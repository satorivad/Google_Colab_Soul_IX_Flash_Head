# %% [markdown]
# <div style='text-align: center; padding: 30px; background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); border-radius: 15px; margin: 10px 0; box-shadow: 0 10px 30px rgba(0,0,0,0.2);'>
#   <h1 style='color: white; margin: 0 0 8px 0; font-size: 2.5em;'>🎬 SoulX FlashHead - AI Talking Head Generator</h1>
#   <h3 style='color: #f0f0f0; margin: 0 0 5px 0; font-weight: 400;'>Audio-Driven Portrait Animation - Created by <strong>AIQUEST</strong></h3>
#   <p style='color: #ddd; margin: 0 0 20px 0;'>Free on Google Colab T4 GPU | Open Source</p>
# </div>
#
# ---
#
# <div align="center">
#
#   <img src="https://img.shields.io/badge/AIQUESTAcademy-blueviolet?style=for-the-badge&logo=youtube&logoColor=white" />
#   <img src="https://img.shields.io/badge/Colab-Free%20Tier-orange?style=for-the-badge&logo=googlecolab&logoColor=white" />
#
#  <br>
#
#   <a href="https://www.youtube.com/@aiquestacademy?sub_confirmation=1">
#     <img src="https://img.shields.io/badge/▶%20Subscribe%20on%20YouTube-FF0000?style=for-the-badge&logo=youtube&logoColor=white" />
#   </a>
#   &nbsp;
#   <a href="https://x.com/aiquestacademy">
#     <img src="https://img.shields.io/badge/Follow%20on%20𝕏-0000?style=for-the-badge&logo=x&logoColor=white" />
#   </a>
#
# </div>
#
# ---
#
#
# ### About This Notebook
#
# This notebook runs **SoulX FlashHead both Lite & Pro** — an audio-driven talking head generator with a full Gradio interface:
#
# | Feature | Description |
# |----|----|
# | **Lite & Pro Models** | Choose between fast Lite or high-quality Pro mode |
# | **Audio-Driven Animation** | Animate portraits with any audio/speech input |
# | **Wav2Vec2 Integration** | Facebook's wav2vec2 for audio feature extraction |
# | **Gradio Web UI** | Easy-to-use interface with shareable public link |
# | **Colab Optimized** | Runs on free T4 GPU with no restart needed |
#
# ### Before You Start
# > Go to **Runtime -> Change runtime type -> T4 GPU**

# %%
# @title Step 1: 🔍 GPU Check & PyTorch Verification
# !nvidia-smi --query-gpu=name,memory.total,driver_version --format=csv
print()

import torch
print(f"PyTorch {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
    try:
        x = torch.zeros(1, device="cuda")
        del x
        print("\n✅ PyTorch CUDA is working!")
    except Exception as e:
        print(f"\n⚠️ CUDA test failed: {e}")
else:
    print("\n❌ No GPU detected! Go to Runtime → Change runtime type → T4 GPU")
# Out:
# name, memory.total [MiB], driver_version
# Tesla T4, 15360 MiB, 580.82.07
#
# PyTorch 2.10.0+cu128
# CUDA available: True
# CUDA version: 12.8
# GPU: Tesla T4
# VRAM: 14.6 GB
#
# ✅ PyTorch CUDA is working!

# %%
# @title Step 2: 📥 Clone Repo & Install System Dependencies
import os

print("📦 Installing system dependencies...")
# !apt-get install -y ffmpeg -q

print("\n📥 Cloning SoulX-FlashHead repository...")
if os.path.exists("/content/SoulX-FlashHead"):
    print("📂 Repository exists, pulling latest...")
    # %cd /content/SoulX-FlashHead
    # !git pull
else:
    # !git clone https://github.com/Soul-AILab/SoulX-FlashHead.git
    # %cd /content/SoulX-FlashHead

# !ls
print("\n✅ Repository cloned & system deps installed!")
# Out:
# 📦 Installing system dependencies...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
#
# 📥 Cloning SoulX-FlashHead repository...
# Cloning into 'SoulX-FlashHead'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 155 (delta 33), reused 26 (delta 17), pack-reused 90 (from 1)
# Receiving objects: 100% (155/155), 6.53 MiB | 14.47 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# /content/SoulX-FlashHead
# assets			 inference_script_multi_gpu_pro.sh
# examples		 inference_script_single_gpu_lite.sh
# flash_head		 inference_script_single_gpu_pro.sh
# generate_video.py	 LICENSE
# gradio_app.py		 README.md
# gradio_app_streaming.py  requirements.txt
#
# ✅ Repository cloned & system deps installed!

# %%
# @title Step 3: ⚙️ Install Python Dependencies
# Strategy: Do NOT replace Colab's default torch. Install deps on top of it.

print("📦 Installing xformers...")
# !pip install -q xformers

print("\n📦 Installing core dependencies (2-3 minutes)...")
# !pip install -q \
    "opencv-python-headless>=4.12.0.88" \
    "diffusers>=0.34.0" \
    "transformers==4.57.3" \
    "tokenizers>=0.20.3" \
    "accelerate>=1.8.1" \
    tqdm imageio easydict ftfy \
    "imageio-ffmpeg" \
    scikit-image \
    loguru \
    "gradio>=5.0.0" \
    pyloudnorm \
    decord \
    librosa \
    "mediapipe>=0.10.13" \
    flask \
    huggingface_hub

print("\n📦 Installing xfuser...")
# !pip install -q "xfuser>=0.4.3" || pip install -q "xfuser>=0.4.3" --no-deps
# !pip install -q yunchang distvae sentencepiece beautifulsoup4 einops 2>/dev/null || true

print("\n✅ All dependencies installed!")
print("─" * 50)

import torch
print(f"🔧 torch: {torch.__version__}")
print(f"🔧 CUDA available: {torch.cuda.is_available()}")
try:
    import xformers; print(f"🔧 xformers: {xformers.__version__}")
except: print("⚠️ xformers: NOT FOUND")
try:
    import xfuser; print(f"🔧 xfuser: OK ({xfuser.__version__})")
except Exception as e: print(f"⚠️ xfuser: FAILED — {e}")
try:
    import diffusers; print(f"🔧 diffusers: {diffusers.__version__}")
except: print("⚠️ diffusers: NOT FOUND")
# Out:
# 📦 Installing xformers...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 53.3 MB/s eta 0:00:00
#
# 📦 Installing core dependencies (2-3 minutes)...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 117.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 118.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 130.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 46.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 15.3 MB/s eta 0:00:00
#
# 📦 Installing xfuser...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.4/241.4 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 5.9 MB/s eta 0:00:00
#
# ✅ All dependencies installed!
# ──────────────────────────────────────────────────
# 🔧 torch: 2.10.0+cu128
# 🔧 CUDA available: True
# 🔧 xformers: 0.0.35
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# ⚠️ xfuser: FAILED — module 'xfuser' has no attribute '__version__'
# 🔧 diffusers: 0.37.1

# %%
# @title Step 4: 📥 Download Models
import os

CKPT_DIR    = "/content/models/SoulX-FlashHead-1_3B"
WAV2VEC_DIR = "/content/models/wav2vec2-base-960h"

os.makedirs(CKPT_DIR, exist_ok=True)
os.makedirs(WAV2VEC_DIR, exist_ok=True)

print("📥 Downloading SoulX-FlashHead-1_3B...")
# !huggingface-cli download Soul-AILab/SoulX-FlashHead-1_3B \
    --local-dir {CKPT_DIR} 2>&1 | grep -E "Fetching|Downloading|100%|%\|"

print("\n📥 Downloading wav2vec2-base-960h...")
# !huggingface-cli download facebook/wav2vec2-base-960h \
    --local-dir {WAV2VEC_DIR} 2>&1 | grep -E "Fetching|Downloading|100%|%\|"

# Quick verify
for name, path in [("FlashHead", CKPT_DIR), ("wav2vec2", WAV2VEC_DIR)]:
    if os.path.exists(path) and len(os.listdir(path)) > 0:
        print(f"✅ {name} downloaded")
    else:
        print(f"❌ {name} MISSING — check above for errors")
# Out:
# 📥 Downloading SoulX-FlashHead-1_3B...
# Fetching 18 files:   0%|          | 0/18 [00:00<?, ?it/s]Downloading 'README.md' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.7870f5054aee546dd4914677d276c4999b5fbdb1.incomplete'
# Downloading 'Model_Pro/diffusion_pytorch_model.safetensors' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/Model_Pro/4SfAgk9U607e8pVunEB9nSiU10k=.e47e61b9023ea1aac60c0c0fff077289bc6cca443c71907e5a76a411480af250.incomplete'
# Downloading 'VAE_LTX/diffusion_pytorch_model.safetensors' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/VAE_LTX/4SfAgk9U607e8pVunEB9nSiU10k=.265ca87cb5dff5e37f924286e957324e282fe7710a952a7dafc0df43883e2010.incomplete'
# Downloading 'Model_Lite/config.json' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/Model_Lite/8_PA_wEVGiVa2goH2H4KQOQpvVY=.8d54568d78e315a926d48136c8a6f6aa5286b005.incomplete'
# Downloading 'Model_Lite/diffusion_pytorch_model.safetensors' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/Model_Lite/4SfAgk9U607e8pVunEB9nSiU10k=.aaf1cde6e80ca23f740aae236c47954249f65b151db133cc0f77d3a138ccdf6e.incomplete'
# Downloading 'VAE_LTX/config.json' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/VAE_LTX/8_PA_wEVGiVa2goH2H4KQOQpvVY=.3a9d81963b21d0c4cfba102fff93676852b52588.incomplete'
# Downloading 'Model_Pro/config.json' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/Model_Pro/8_PA_wEVGiVa2goH2H4KQOQpvVY=.24379b09c3399c1fbb4932548c04003f8f560442.incomplete'
# Downloading '.gitattributes' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.15a20774060b6b9d5696483bd4975ee03d04721c.incomplete'
# Fetching 18 files:   6%|▌         | 1/18 [00:00<00:04,  3.84it/s]Downloading 'assets/flashhead_logo.png' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/dgFPzBcE81LmbEBskY2eB8ykaYQ=.75baa07ed2e3bc190cecbd2a0484ca70e324ee394c06a1bbf2a5a45db214d663.incomplete'
# Downloading 'VAE_Wan/Wan2.1_VAE.pth' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/VAE_Wan/OZTShqo6Di7rh0SEswnfwSjKa9w=.38071ab59bd94681c686fa51d75a1968f64e470262043be31f7a094e442fd981.incomplete'
# Downloading 'assets/chengdu.mp4' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/u_cEAApgglP4muKekggz70OFJXU=.95bab76c675fa176b1c2b1be54fe4ac5cb2ad4fb7868196be8a380b608e7b49d.incomplete'
# Downloading 'assets/einstein.mp4' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/XU1q5pEZy0m1fNhWm_2tpR2_NcY=.c10118b169916df66ff4ac4258ae3b8e959f51b2ba52f6551e1442125655f899.incomplete'
# Downloading 'assets/qitiandasheng.mp4' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/CYTXTvLYlCDGeXSQLZsqYHGBNiA=.72a340f8b74936961c4525592e8f07280f1cc771efa3e0dbc84b731ece6e3198.incomplete'
# Downloading 'assets/soul_event_link.png' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/fkgspUo2rfb1_wl46aJGxfTVZVQ=.0debde1e77131dc06aeb0d7d5df4d2c4e043d108df7438d4676668ffc7ca60b3.incomplete'
# Downloading 'assets/wechat_group.png' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/FD2ldUlIly6RkIuQXZiO4ucKuOk=.767697b6f33fcc508d775957fbec4e3fccc0d32170df7758c7cf9d8c1c344dd4.incomplete'
# Downloading 'assets/soul_group.png' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/assets/3SiTgwOxULZyR4IYATfrBWN5hfI=.9ce0619712325f6533103fda8290352e305fc46a.incomplete'
# Downloading 'config.json' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.75ecfcb904b614fd12edeaa66bcddbcbc425b043.incomplete'
# Downloading 'model_index.json' to '/content/models/SoulX-FlashHead-1_3B/.cache/huggingface/download/GdzJ-MSUxwmuXEKVy-ZpuQNVts8=.32dfa9a8714bacb4779761b00b41f3441a23cbb1.incomplete'
# Fetching 18 files: 100%|██████████| 18/18 [02:31<00:00,  8.42s/it]
#
# 📥 Downloading wav2vec2-base-960h...
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]Downloading 'model.safetensors' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/xGOKKLRSlIhH692hSVvI1-gpoa8=.8aa76ab2243c81747a1f832954586bc566090c83a0ac167df6f31f0fa917d74a.incomplete'
# Downloading 'config.json' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.8ca9cc7496e145e37d09cec17d0c3bf9b8523c8e.incomplete'
# Downloading 'preprocessor_config.json' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/PYH5dHjks7Ei0Yd3X0Z8xIwsCNQ=.3f24dc078fcba55ee1d417a413847ead40c093a3.incomplete'
# Downloading 'pytorch_model.bin' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/Q1p2l2BzM1m6P5jKvr8WTq1TUio=.c34f9827b034a1b9141dbf6f652f8a60eda61cdf5771c9e05bfa99033c92cd96.incomplete'
# Downloading 'special_tokens_map.json' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.25bc39604f72700b3b8e10bd69bb2f227157edd1.incomplete'
# Downloading 'feature_extractor_config.json' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/4VpR2OeiJgUtBk492d08IL99QYQ=.52fdd74dc06f40033506e402269fbde5e7adc21d.incomplete'
# Downloading '.gitattributes' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.cf6d51fc9b1a671c35e92d6bd009880937aaa12d.incomplete'
# Fetching 11 files:   9%|▉         | 1/11 [00:00<00:01,  5.18it/s]Downloading 'README.md' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.c7fe2047d7ac9b9816848c657b2a492ee95b264b.incomplete'
# Downloading 'tf_model.h5' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/a7eHxRFT3OeMBIFg52k2nfj5m7w=.412742825972a6e2e877255ccd8b3416e618df15a7f1e5e4f736aa3632ce33b5.incomplete'
# Downloading 'tokenizer_config.json' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.978a15a96dbb2d23e2afbc70137cae6c5ce38c8d.incomplete'
# Downloading 'vocab.json' to '/content/models/wav2vec2-base-960h/.cache/huggingface/download/j3m-Hy6QvBddw8RXA1uSWl1AJ0c=.88181b954aa14df68be9b444b3c36585f3078c0a.incomplete'
# Fetching 11 files:  45%|████▌     | 5/11 [00:51<01:05, 10.98s/it]Download complete. Moving file to /content/models/wav2vec2-base-960h/tf_model.h5
# Fetching 11 files: 100%|██████████| 11/11 [00:52<00:00,  4.80s/it]
# ✅ FlashHead downloaded
# ✅ wav2vec2 downloaded

# %%
# @title Step 5: 🔧 Patch All Files (Paths + Share + 16:9 Output)
import os, re
os.chdir("/content/SoulX-FlashHead")

# Reset ALL files to clean state
# !git checkout -- gradio_app.py 2>/dev/null
# !git checkout -- flash_head/utils/facecrop.py 2>/dev/null
# !git checkout -- flash_head/utils/cpu_face_handler.py 2>/dev/null

# ═══════════════════════════════════════════════════
# PART 0: Replace CPUFaceHandler with OpenCV (mediapipe is broken)
# ═══════════════════════════════════════════════════
handler_path = "/content/SoulX-FlashHead/flash_head/utils/cpu_face_handler.py"
handler_code = '''import cv2
import numpy as np
from typing import Tuple, List

class CPUFaceHandler:
    """OpenCV-based face detection (replaces broken mediapipe)."""

    def __init__(self, model_selection: int = 1, min_detection_confidence: float = 0.0):
        # Try DNN first (more accurate), fall back to Haar
        proto = "/content/SoulX-FlashHead/deploy.prototxt"
        caffe = "/content/SoulX-FlashHead/res10_300x300_ssd_iter_140000.caffemodel"
        self.use_dnn = False
        self.use_haar = False

        # Download DNN model if not present
        import urllib.request
        if not os.path.exists(proto):
            try:
                urllib.request.urlretrieve(
                    "https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt",
                    proto)
            except: pass
        if not os.path.exists(caffe):
            try:
                urllib.request.urlretrieve(
                    "https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel",
                    caffe)
            except: pass

        if os.path.exists(proto) and os.path.exists(caffe):
            self.net = cv2.dnn.readNetFromCaffe(proto, caffe)
            self.use_dnn = True
        else:
            cascade_path = cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
            self.cascade = cv2.CascadeClassifier(cascade_path)
            self.use_haar = True

    def detect(self, image: np.ndarray) -> Tuple[List, List]:
        bboxs, scores = [], []
        img_h, img_w = image.shape[:2]

        if self.use_dnn:
            blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), (104.0, 177.0, 123.0))
            self.net.setInput(blob)
            detections = self.net.forward()
            for i in range(detections.shape[2]):
                confidence = float(detections[0, 0, i, 2])
                if confidence > 0.5:
                    # Return RELATIVE coordinates (same as original mediapipe handler)
                    x1 = detections[0, 0, i, 3]
                    y1 = detections[0, 0, i, 4]
                    x2 = detections[0, 0, i, 5]
                    y2 = detections[0, 0, i, 6]
                    bboxs.append([float(x1), float(y1), float(x2), float(y2)])
                    scores.append(confidence)
        elif self.use_haar:
            gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
            faces = self.cascade.detectMultiScale(gray, 1.1, 5, minSize=(30, 30))
            for (x, y, w, h) in faces:
                # Convert to RELATIVE coordinates
                bboxs.append([x/img_w, y/img_h, (x+w)/img_w, (y+h)/img_h])
                scores.append(1.0)

        return bboxs, scores

    def __call__(self, image: np.ndarray) -> Tuple[List, List]:
        return self.detect(image)
'''

import os as _os
with open(handler_path, "w") as f:
    f.write("import os\n" + handler_code)
print("✅ Replaced CPUFaceHandler with OpenCV (no mediapipe)")

# ═══════════════════════════════════════════════════
# PART 1: Patch facecrop.py to SAVE the crop bbox
# ═══════════════════════════════════════════════════
facecrop_path = "/content/SoulX-FlashHead/flash_head/utils/facecrop.py"
with open(facecrop_path, "r") as f:
    fc_code = f.read()

fc_code = fc_code.replace(
    'import os',
    'import os\nimport json\n\n_LAST_CROP_BBOX = None'
)

fc_code = fc_code.replace(
    '    crop_face = face_image.crop(scaled_bbox)',
    '    global _LAST_CROP_BBOX\n'
    '    _LAST_CROP_BBOX = scaled_bbox + [img_w, img_h]\n'
    '    try:\n'
    '        with open("/tmp/_flashhead_crop_bbox.json", "w") as _bf:\n'
    '            json.dump({"bbox": scaled_bbox, "img_w": img_w, "img_h": img_h}, _bf)\n'
    '    except: pass\n'
    '    crop_face = face_image.crop(scaled_bbox)'
)

with open(facecrop_path, "w") as f:
    f.write(fc_code)
print("✅ Patched facecrop.py to save crop bbox")

# ═══════════════════════════════════════════════════
# PART 2: Patch gradio_app.py
# ═══════════════════════════════════════════════════
filepath = "/content/SoulX-FlashHead/gradio_app.py"
with open(filepath, "r") as f:
    code = f.read()

# Fix model paths
code = code.replace('value="models/SoulX-FlashHead-1_3B"', 'value="/content/models/SoulX-FlashHead-1_3B"')
code = code.replace('value="models/wav2vec2-base-960h"', 'value="/content/models/wav2vec2-base-960h"')

# Default to lite
code = code.replace('value="pro",', 'value="lite",')

# Default face crop ON
code = code.replace(
    'label="Use Face Crop",\n                value=False,',
    'label="Use Face Crop",\n                value=True,'
)

# Share mode
if 'app.launch(share=True' not in code:
    code = code.replace('app.launch()', 'app.launch(share=True, debug=True)')

# Branding
match = re.search(r'^( *)gr\.Markdown\("# ⚡ SoulX-FlashHead Video Generator"\)', code, re.MULTILINE)
if match:
    old_line = match.group(0)
    ind = match.group(1)
    brand_html = (
        '<div style="text-align:center; padding:25px; '
        'background:linear-gradient(135deg,#667eea 0%,#764ba2 100%); '
        'border-radius:12px; box-shadow:0 8px 16px rgba(0,0,0,0.2); margin-bottom:20px;">'
        '<h1 style="font-size:2.2em; margin:0; color:white;">🎬 SoulX FlashHead Lite - AI Talking Head</h1>'
        '<p style="font-size:1.1em; color:rgba(255,255,255,0.9); margin:6px 0 12px;">'
        'Audio-Driven Portrait Animation | Lite &amp; Pro Models</p>'
        '<div style="display:flex; justify-content:center; gap:12px; flex-wrap:wrap;">'
        '<a href="https://www.youtube.com/@AiQuestacademy" target="_blank" '
        'style="background:#FF0000; color:#fff; padding:8px 18px; border-radius:8px; '
        'text-decoration:none; font-weight:600; font-size:0.95em;">'
        '▶ YouTube - AIQUEST</a>'
        '<a href="https://x.com/AiQuestacademy" target="_blank" '
        'style="background:#000; color:#fff; padding:8px 18px; border-radius:8px; '
        'text-decoration:none; font-weight:600; font-size:0.95em;">'
        '𝕏 Follow on X</a></div>'
        '<p style="margin-top:10px; font-size:0.85em; color:rgba(255,255,255,0.7);">'
        'Notebook by <b>AIQUEST</b> — Subscribe for more AI tools &amp; tutorials!</p></div>'
    )
    new_line = ind + 'gr.HTML(' + repr(brand_html) + ')'
    code = code.replace(old_line, new_line)
    print("✅ Branding injected")

# ── Inject post-processing into run_inference ──
run_inf_pattern = re.search(
    r'(logger\.info\(f"Saved to \{final_video_path\}"\))\s*\n(\s*)(return final_video_path)',
    code
)
if run_inf_pattern:
    old_block = run_inf_pattern.group(0)
    ind = run_inf_pattern.group(2)
    new_block = (
        run_inf_pattern.group(1) + '\n'
        + ind + '# ── 16:9 Aspect Ratio Post-Processing ──\n'
        + ind + 'try:\n'
        + ind + '    final_video_path = _composite_to_original(final_video_path, cond_image)\n'
        + ind + 'except Exception as e:\n'
        + ind + '    import traceback; logger.error(f"COMPOSITE FAILED: {e}\\n{traceback.format_exc()}")\n'
        + ind + 'return final_video_path'
    )
    code = code.replace(old_block, new_block)
    print("✅ Post-processing injected into run_inference")

# ── Inject into run_multi_gpu_inference ──
multi_pattern = re.search(
    r'(if os\.path\.exists\(save_path\):)\s*\n(\s*)(return save_path)',
    code
)
if multi_pattern:
    old_block2 = multi_pattern.group(0)
    ind2 = multi_pattern.group(2)
    new_block2 = (
        multi_pattern.group(1) + '\n'
        + ind2 + '# ── 16:9 Aspect Ratio Post-Processing ──\n'
        + ind2 + 'try:\n'
        + ind2 + '    save_path = _composite_to_original(save_path, cond_image)\n'
        + ind2 + 'except Exception as e:\n'
        + ind2 + '    import traceback; logger.error(f"COMPOSITE FAILED: {e}\\n{traceback.format_exc()}")\n'
        + ind2 + 'return save_path'
    )
    code = code.replace(old_block2, new_block2)
    print("✅ Post-processing injected into run_multi_gpu_inference")

# ── Add composite function ──
first_def = code.index("\ndef ")
composite_func = '''
def _composite_to_original(video_path, original_image_path):
    """
    Reads the EXACT crop bbox saved by facecrop.py during model inference,
    then pastes each 512x512 generated frame back into that exact region.
    """
    import cv2, json, numpy as np, subprocess

    bbox_file = "/tmp/_flashhead_crop_bbox.json"
    if not os.path.exists(bbox_file):
        logger.info("No crop bbox file found — face_crop was likely disabled, skipping composite")
        return video_path

    with open(bbox_file, "r") as f:
        crop_data = json.load(f)

    crop_x1, crop_y1, crop_x2, crop_y2 = crop_data["bbox"]
    orig_img_w = crop_data["img_w"]
    orig_img_h = crop_data["img_h"]

    os.remove(bbox_file)

    aspect = max(orig_img_w, orig_img_h) / max(min(orig_img_w, orig_img_h), 1)
    if aspect < 1.15:
        logger.info(f"Original {orig_img_w}x{orig_img_h} is ~square, skipping composite")
        return video_path

    crop_w = crop_x2 - crop_x1
    crop_h = crop_y2 - crop_y1

    logger.info(f"COMPOSITE: using EXACT model bbox ({crop_x1},{crop_y1})-({crop_x2},{crop_y2}) = {crop_w}x{crop_h} in {orig_img_w}x{orig_img_h}")

    orig = cv2.imread(original_image_path)
    if orig is None:
        logger.warning(f"Could not read original image: {original_image_path}")
        return video_path

    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS) or 25.0
    output_path = video_path.replace(".mp4", "_ar.mp4")

    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (orig_img_w, orig_img_h))

    mask = np.ones((crop_h, crop_w), dtype=np.float32)
    feather = max(min(crop_w, crop_h) // 12, 6)
    for i in range(feather):
        a = i / feather
        mask[i, :] *= a
        mask[-(i+1), :] *= a
        mask[:, i] *= a
        mask[:, -(i+1)] *= a
    mask_3ch = mask[:, :, np.newaxis]

    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        resized = cv2.resize(frame, (crop_w, crop_h), interpolation=cv2.INTER_LANCZOS4)
        canvas = orig.copy()
        roi = canvas[crop_y1:crop_y2, crop_x1:crop_x2].astype(np.float32)
        blended = (resized.astype(np.float32) * mask_3ch + roi * (1 - mask_3ch)).astype(np.uint8)
        canvas[crop_y1:crop_y2, crop_x1:crop_x2] = blended
        out.write(canvas)
        frame_count += 1

    cap.release()
    out.release()

    final_path = output_path.replace(".mp4", "_final.mp4")
    subprocess.run(["ffmpeg", "-y", "-i", output_path, "-i", video_path,
                    "-c:v", "libx264", "-c:a", "aac", "-map", "0:v", "-map", "1:a",
                    "-shortest", final_path], capture_output=True)

    if os.path.exists(final_path) and os.path.getsize(final_path) > 0:
        os.replace(final_path, video_path)
        if os.path.exists(output_path):
            os.remove(output_path)
        logger.info(f"✅ Composited {frame_count} frames -> {orig_img_w}x{orig_img_h}, saved to {video_path}")
        return video_path

    if os.path.exists(output_path):
        os.replace(output_path, video_path)
    return video_path

'''
code = code[:first_def] + composite_func + code[first_def:]

with open(filepath, "w") as f:
    f.write(code)

# ═══════════════════════════════════════════════════
# Verify everything
# ═══════════════════════════════════════════════════
with open(filepath, "r") as f:
    final = f.read()
with open(facecrop_path, "r") as f:
    fc_final = f.read()
with open(handler_path, "r") as f:
    handler_final = f.read()

checks = [
    ("_composite_to_original(final_video_path, cond_image)" in final, "Post-process in run_inference"),
    ("_composite_to_original(save_path, cond_image)" in final, "Post-process in run_multi_gpu"),
    ("def _composite_to_original" in final, "Composite function"),
    ("_flashhead_crop_bbox.json" in final, "Reads exact bbox from model"),
    ("_flashhead_crop_bbox.json" in fc_final, "facecrop.py saves bbox"),
    ("mediapipe" not in handler_final, "CPUFaceHandler uses OpenCV (no mediapipe)"),
    ("cv2.dnn" in handler_final, "DNN face detector in handler"),
    ("value=True," in final and "Use Face Crop" in final, "Face crop defaults ON"),
    ("/content/models/" in final, "Model paths"),
    ("share=True" in final, "Share mode"),
]
print("\n── Verification ──")
for ok, label in checks:
    print(f"{'✅' if ok else '❌'} {label}")

# Test that the handler actually works
print("\n── Handler Test ──")
try:
    import sys
    for mod in list(sys.modules.keys()):
        if "face_handler" in mod or "facecrop" in mod:
            del sys.modules[mod]
    from flash_head.utils.cpu_face_handler import CPUFaceHandler
    handler = CPUFaceHandler()
    print(f"✅ CPUFaceHandler initialized (dnn={handler.use_dnn}, haar={handler.use_haar})")
except Exception as e:
    print(f"❌ CPUFaceHandler FAILED: {e}")
# Out:
# ✅ Replaced CPUFaceHandler with OpenCV (no mediapipe)
# ✅ Patched facecrop.py to save crop bbox
# ✅ Branding injected
# ✅ Post-processing injected into run_inference
# ✅ Post-processing injected into run_multi_gpu_inference
#
# ── Verification ──
# ✅ Post-process in run_inference
# ✅ Post-process in run_multi_gpu
# ✅ Composite function
# ✅ Reads exact bbox from model
# ✅ facecrop.py saves bbox
# ❌ CPUFaceHandler uses OpenCV (no mediapipe)
# ✅ DNN face detector in handler
# ❌ Face crop defaults ON
# ✅ Model paths
# ✅ Share mode
#
# ── Handler Test ──
# ✅ CPUFaceHandler initialized (dnn=True, haar=False)

# %%
# @title Quick Fix: Force face_crop default ON
filepath = "/content/SoulX-FlashHead/gradio_app.py"
with open(filepath, "r") as f:
    code = f.read()

import re
# Match the checkbox regardless of whitespace
code = re.sub(
    r'(use_face_crop_input\s*=\s*gr\.Checkbox\([^)]*?)value\s*=\s*False',
    r'\1value=True',
    code
)

with open(filepath, "w") as f:
    f.write(code)

# Verify
with open(filepath, "r") as f:
    final = f.read()

match = re.search(r'use_face_crop_input.*?value\s*=\s*(True|False)', final, re.DOTALL)
print(f"✅ Face crop default: {match.group(1)}" if match else "❌ Not found")
# Out:
# ✅ Face crop default: True

# %%
# @title Step 6: 🚀 Launch SoulX FlashHead Gradio UI
# %cd /content/SoulX-FlashHead

print("🚀 Launching SoulX FlashHead Lite...")
print("🔗 Watch for the public Gradio URL below!\n")

# !python gradio_app.py
# Out:
# /content/SoulX-FlashHead
# 🚀 Launching SoulX FlashHead Lite...
# 🔗 Watch for the public Gradio URL below!
#
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# /content/SoulX-FlashHead/gradio_app.py:386: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(title="SoulX-FlashHead Video Generator", theme=gr.themes.Soft()) as app:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://0cf4bb0b4fc5a19897.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 2026-05-13 09:56:21.646 | INFO     | __main__:run_inference:253 - Loading pipeline with ckpt_dir=/content/models/SoulX-FlashHead-1_3B, wav2vec_dir=/content/models/wav2vec2-base-960h
# 2026-05-13 09:56:21.647 | INFO     | flash_head.inference:get_pipeline:17 - ulysses_degree: 1, ring_degree: 1, device: cuda
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at /content/models/wav2vec2-base-960h and are newly initialized: ['masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# W0513 09:57:12.308000 3510 torch/_inductor/utils.py:1679] [0/0] Not enough SMs to use max_autotune_gemm mode
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/variables/functions.py:2056: UserWarning: Dynamo detected a call to a `functools.lru_cache`-wrapped function. Dynamo ignores the cache wrapper and directly traces the wrapped function. Silent incorrectness is only a *potential* risk, not something we have observed. Enable TORCH_LOGS="+dynamo" for a DEBUG stack trace.
#   torch._dynamo.utils.warn_once(msg)
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# 2026-05-13 09:57:47.464 | INFO     | __main__:run_inference:297 - Data preparation done. Start to generate video...
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/lowering.py:2156: UserWarning: Torchinductor does not support code generation for complex operators. Performance may be worse than eager.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /content/SoulX-FlashHead/flash_head/src/modules/flash_head_model.py:544: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(dtype=torch.float32):
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# [generate] model denoise per step: 79.45211458206177s
# /content/SoulX-FlashHead/flash_head/src/modules/flash_head_model.py:544: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(dtype=torch.float32):
# [generate] model denoise per step: 1.7816386222839355s
# [generate] model denoise per step: 1.8242383003234863s
# [generate] model denoise per step: 1.8360414505004883s
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:2900: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# [generate] decode video frames: 25.541574478149414s
# [generate] color correction: 0.06313586235046387s
# [generate] encode motion frames: 1.6319730281829834s
# 2026-05-13 09:59:40.409 | INFO     | __main__:run_inference:363 - Generate video chunk-0 done, cost time: 112.14s
# /content/SoulX-FlashHead/flash_head/src/modules/flash_head_model.py:544: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(dtype=torch.float32):
# [generate] model denoise per step: 1.8552286624908447s
# [generate] model denoise per step: 1.8444814682006836s
# [generate] model denoise per step: 1.8804187774658203s
# [generate] model denoise per step: 1.902813196182251s
# [generate] decode video frames: 6.417756080627441s
# [generate] color correction: 0.04819846153259277s
# [generate] encode motion frames: 1.6897680759429932s
# 2026-05-13 09:59:56.172 | INFO     | __main__:run_inference:363 - Generate video chunk-1 done, cost time: 15.64s
# [generate] model denoise per step: 1.8495192527770996s
# [generate] model denoise per step: 1.8344142436981201s
# [generate] model denoise per step: 1.833923578262329s
# [generate] model denoise per step: 1.8318655490875244s
# [generate] decode video frames: 5.7437217235565186s
# [generate] color correction: 0.04602861404418945s
# [generate] encode motion frames: 1.534614086151123s
# 2026-05-13 10:00:10.933 | INFO     | __main__:run_inference:363 - Generate video chunk-2 done, cost time: 14.68s
# [generate] model denoise per step: 1.754326343536377s
# [generate] model denoise per step: 1.7448275089263916s
# [generate] model denoise per step: 1.7423920631408691s
# [generate] model denoise per step: 1.730581283569336s
# [generate] decode video frames: 5.476656913757324s
# [generate] color correction: 0.04453587532043457s
# [generate] encode motion frames: 1.4687910079956055s
# 2026-05-13 10:00:24.991 | INFO     | __main__:run_inference:363 - Generate video chunk-3 done, cost time: 13.97s
# [generate] model denoise per step: 1.706993579864502s
# [generate] model denoise per step: 1.7120046615600586s
# [generate] model denoise per step: 1.7062199115753174s
# [generate] model denoise per step: 1.7166693210601807s
# [generate] decode video frames: 5.439313173294067s
# [generate] color correction: 0.0452418327331543s
# [generate] encode motion frames: 1.4781951904296875s
# 2026-05-13 10:00:38.896 | INFO     | __main__:run_inference:363 - Generate video chunk-4 done, cost time: 13.81s
# [generate] model denoise per step: 1.7302837371826172s
# [generate] model denoise per step: 1.7285332679748535s
# [generate] model denoise per step: 1.7446045875549316s
# [generate] model denoise per step: 1.7465786933898926s
# [generate] decode video frames: 5.59774923324585s
# [generate] color correction: 0.046503305435180664s
# [generate] encode motion frames: 1.5237488746643066s
# 2026-05-13 10:00:53.104 | INFO     | __main__:run_inference:363 - Generate video chunk-5 done, cost time: 14.12s
# [generate] model denoise per step: 1.77764892578125s
# [generate] model denoise per step: 1.7889385223388672s
# [generate] model denoise per step: 1.7932205200195312s
# [generate] model denoise per step: 1.8167853355407715s
# [generate] decode video frames: 5.7902421951293945s
# [generate] color correction: 0.04720902442932129s
# [generate] encode motion frames: 1.5740830898284912s
# 2026-05-13 10:01:07.793 | INFO     | __main__:run_inference:363 - Generate video chunk-6 done, cost time: 14.59s
# [generate] model denoise per step: 1.8387391567230225s
# [generate] model denoise per step: 1.834167718887329s
# [generate] model denoise per step: 1.8349721431732178s
# [generate] model denoise per step: 1.8357579708099365s
# [generate] decode video frames: 5.783034563064575s
# [generate] color correction: 0.04743003845214844s
# [generate] encode motion frames: 1.55800199508667s
# 2026-05-13 10:01:22.640 | INFO     | __main__:run_inference:363 - Generate video chunk-7 done, cost time: 14.74s
# [generate] model denoise per step: 1.8035485744476318s
# [generate] model denoise per step: 1.7978014945983887s
# [generate] model denoise per step: 1.7980725765228271s
# [generate] model denoise per step: 1.7978155612945557s
# [generate] decode video frames: 5.697231292724609s
# [generate] color correction: 0.045537471771240234s
# [generate] encode motion frames: 1.5311603546142578s
# 2026-05-13 10:01:37.201 | INFO     | __main__:run_inference:363 - Generate video chunk-8 done, cost time: 14.48s
# [generate] model denoise per step: 1.7744135856628418s
# [generate] model denoise per step: 1.7745041847229004s
# [generate] model denoise per step: 1.766007900238037s
# [generate] model denoise per step: 1.769697666168213s
# [generate] decode video frames: 5.619710445404053s
# [generate] color correction: 0.045381784439086914s
# [generate] encode motion frames: 1.5117838382720947s
# 2026-05-13 10:01:51.556 | INFO     | __main__:run_inference:363 - Generate video chunk-9 done, cost time: 14.27s
# [generate] model denoise per step: 1.7551648616790771s
# [generate] model denoise per step: 1.755948781967163s
# [generate] model denoise per step: 1.759185552597046s
# [generate] model denoise per step: 1.762864589691162s
# [generate] decode video frames: 5.623637914657593s
# [generate] color correction: 0.045023441314697266s
# [generate] encode motion frames: 1.5069308280944824s
# 2026-05-13 10:02:05.857 | INFO     | __main__:run_inference:363 - Generate video chunk-10 done, cost time: 14.22s
# [generate] model denoise per step: 1.7597858905792236s
# [generate] model denoise per step: 1.7682747840881348s
# [generate] model denoise per step: 1.778282880783081s
# [generate] model denoise per step: 1.7798948287963867s
# [generate] decode video frames: 5.6569554805755615s
# [generate] color correction: 0.04523968696594238s
# [generate] encode motion frames: 1.526350736618042s
# 2026-05-13 10:02:20.274 | INFO     | __main__:run_inference:363 - Generate video chunk-11 done, cost time: 14.32s
# [generate] model denoise per step: 1.7780141830444336s
# [generate] model denoise per step: 1.7875430583953857s
# [generate] model denoise per step: 1.7884242534637451s
# [generate] model denoise per step: 1.7860984802246094s
# [generate] decode video frames: 5.680542469024658s
# [generate] color correction: 0.045786380767822266s
# [generate] encode motion frames: 1.543304443359375s
# 2026-05-13 10:02:34.776 | INFO     | __main__:run_inference:363 - Generate video chunk-12 done, cost time: 14.42s
# [generate] model denoise per step: 1.7912240028381348s
# [generate] model denoise per step: 1.7873573303222656s
# [generate] model denoise per step: 1.7945482730865479s
# [generate] model denoise per step: 1.7859139442443848s
# [generate] decode video frames: 5.704113960266113s
# [generate] color correction: 0.04707026481628418s
# [generate] encode motion frames: 1.542038917541504s
# 2026-05-13 10:02:49.338 | INFO     | __main__:run_inference:363 - Generate video chunk-13 done, cost time: 14.46s
# [generate] model denoise per step: 1.7828633785247803s
# [generate] model denoise per step: 1.7860770225524902s
# [generate] model denoise per step: 1.7920684814453125s
# [generate] model denoise per step: 1.78670072555542s
# [generate] decode video frames: 5.7088329792022705s
# [generate] color correction: 0.045941829681396484s
# [generate] encode motion frames: 1.5401825904846191s
# 2026-05-13 10:03:03.875 | INFO     | __main__:run_inference:363 - Generate video chunk-14 done, cost time: 14.45s
# [generate] model denoise per step: 1.7935361862182617s
# [generate] model denoise per step: 1.802215576171875s
# [generate] model denoise per step: 1.7989206314086914s
# [generate] model denoise per step: 1.7964727878570557s
# [generate] decode video frames: 5.737017393112183s
# [generate] color correction: 0.04628133773803711s
# [generate] encode motion frames: 1.5440795421600342s
# 2026-05-13 10:03:18.488 | INFO     | __main__:run_inference:363 - Generate video chunk-15 done, cost time: 14.52s
# [generate] model denoise per step: 1.7945029735565186s
# [generate] model denoise per step: 1.7963426113128662s
# [generate] model denoise per step: 1.799255132675171s
# [generate] model denoise per step: 1.7991750240325928s
# [generate] decode video frames: 5.717552423477173s
# [generate] color correction: 0.04545927047729492s
# [generate] encode motion frames: 1.5461375713348389s
# 2026-05-13 10:03:33.079 | INFO     | __main__:run_inference:363 - Generate video chunk-16 done, cost time: 14.50s
# [generate] model denoise per step: 1.7956018447875977s
# [generate] model denoise per step: 1.7939190864562988s
# [generate] model denoise per step: 1.7897069454193115s
# [generate] model denoise per step: 1.7967534065246582s
# [generate] decode video frames: 5.710782289505005s
# [generate] color correction: 0.04608726501464844s
# [generate] encode motion frames: 1.5387187004089355s
# 2026-05-13 10:03:47.642 | INFO     | __main__:run_inference:363 - Generate video chunk-17 done, cost time: 14.48s
# [generate] model denoise per step: 1.7913360595703125s
# [generate] model denoise per step: 1.7949402332305908s
# [generate] model denoise per step: 1.7868611812591553s
# [generate] model denoise per step: 1.7990713119506836s
# [generate] decode video frames: 5.714985132217407s
# [generate] color correction: 0.04623150825500488s
# [generate] encode motion frames: 1.547583818435669s
# 2026-05-13 10:04:02.215 | INFO     | __main__:run_inference:363 - Generate video chunk-18 done, cost time: 14.49s
# [generate] model denoise per step: 1.7860074043273926s
# [generate] model denoise per step: 1.7985789775848389s
# [generate] model denoise per step: 1.7999515533447266s
# [generate] model denoise per step: 1.7996277809143066s
# [generate] decode video frames: 5.700968503952026s
# [generate] color correction: 0.04593658447265625s
# [generate] encode motion frames: 1.5441830158233643s
# 2026-05-13 10:04:16.810 | INFO     | __main__:run_inference:363 - Generate video chunk-19 done, cost time: 14.48s
# [generate] model denoise per step: 1.780341386795044s
# [generate] model denoise per step: 1.7939536571502686s
# [generate] model denoise per step: 1.7856206893920898s
# [generate] model denoise per step: 1.7951874732971191s
# [generate] decode video frames: 5.720258951187134s
# [generate] color correction: 0.04549145698547363s
# [generate] encode motion frames: 1.5444707870483398s
# 2026-05-13 10:04:31.367 | INFO     | __main__:run_inference:363 - Generate video chunk-20 done, cost time: 14.47s
# [generate] model denoise per step: 1.7887811660766602s
# [generate] model denoise per step: 1.7910995483398438s
# [generate] model denoise per step: 1.7934980392456055s
# [generate] model denoise per step: 1.7993342876434326s
# [generate] decode video frames: 5.713402509689331s
# [generate] color correction: 0.04556679725646973s
# [generate] encode motion frames: 1.5477290153503418s
# 2026-05-13 10:04:45.937 | INFO     | __main__:run_inference:363 - Generate video chunk-21 done, cost time: 14.49s
# [generate] model denoise per step: 1.7889161109924316s
# [generate] model denoise per step: 1.786803960800171s
# [generate] model denoise per step: 1.7986235618591309s
# [generate] model denoise per step: 1.8026783466339111s
# [generate] decode video frames: 5.723399639129639s
# [generate] color correction: 0.04548025131225586s
# [generate] encode motion frames: 1.5377731323242188s
# 2026-05-13 10:05:00.515 | INFO     | __main__:run_inference:363 - Generate video chunk-22 done, cost time: 14.49s
# [generate] model denoise per step: 1.7948760986328125s
# [generate] model denoise per step: 1.7949607372283936s
# [generate] model denoise per step: 1.791548252105713s
# [generate] model denoise per step: 1.8003947734832764s
# [generate] decode video frames: 5.704040765762329s
# [generate] color correction: 0.04608488082885742s
# [generate] encode motion frames: 1.5466673374176025s
# 2026-05-13 10:05:15.085 | INFO     | __main__:run_inference:363 - Generate video chunk-23 done, cost time: 14.48s
# [generate] model denoise per step: 1.794964075088501s
# [generate] model denoise per step: 1.800719976425171s
# [generate] model denoise per step: 1.800389289855957s
# [generate] model denoise per step: 1.7983746528625488s
# [generate] decode video frames: 5.722331523895264s
# [generate] color correction: 0.04613161087036133s
# [generate] encode motion frames: 1.5397617816925049s
# 2026-05-13 10:05:29.686 | INFO     | __main__:run_inference:363 - Generate video chunk-24 done, cost time: 14.51s
# [generate] model denoise per step: 1.7903027534484863s
# [generate] model denoise per step: 1.7979540824890137s
# [generate] model denoise per step: 1.790651798248291s
# [generate] model denoise per step: 1.790269374847412s
# [generate] decode video frames: 5.718241930007935s
# [generate] color correction: 0.047127723693847656s
# [generate] encode motion frames: 1.5378782749176025s
# 2026-05-13 10:05:44.271 | INFO     | __main__:run_inference:363 - Generate video chunk-25 done, cost time: 14.48s
# [generate] model denoise per step: 1.7809007167816162s
# [generate] model denoise per step: 1.7956156730651855s
# [generate] model denoise per step: 1.787595272064209s
# [generate] model denoise per step: 1.7935426235198975s
# [generate] decode video frames: 5.719714403152466s
# [generate] color correction: 0.04526543617248535s
# [generate] encode motion frames: 1.5458462238311768s
# 2026-05-13 10:05:58.831 | INFO     | __main__:run_inference:363 - Generate video chunk-26 done, cost time: 14.47s
# [generate] model denoise per step: 1.790740728378296s
# [generate] model denoise per step: 1.78594970703125s
# [generate] model denoise per step: 1.7960336208343506s
# [generate] model denoise per step: 1.794745683670044s
# [generate] decode video frames: 5.72055983543396s
# [generate] color correction: 0.04585385322570801s
# [generate] encode motion frames: 1.5484840869903564s
# 2026-05-13 10:06:13.406 | INFO     | __main__:run_inference:363 - Generate video chunk-27 done, cost time: 14.49s
# [generate] model denoise per step: 1.7817211151123047s
# [generate] model denoise per step: 1.79478120803833s
# [generate] model denoise per step: 1.7903268337249756s
# [generate] model denoise per step: 1.790574073791504s
# [generate] decode video frames: 5.707038402557373s
# [generate] color correction: 0.04629778861999512s
# [generate] encode motion frames: 1.54667067527771s
# 2026-05-13 10:06:27.963 | INFO     | __main__:run_inference:363 - Generate video chunk-28 done, cost time: 14.46s
# [generate] model denoise per step: 1.788355827331543s
# [generate] model denoise per step: 1.7899928092956543s
# [generate] model denoise per step: 1.788362741470337s
# [generate] model denoise per step: 1.7946035861968994s
# [generate] decode video frames: 5.703344106674194s
# [generate] color correction: 0.045366525650024414s
# [generate] encode motion frames: 1.541508674621582s
# 2026-05-13 10:06:42.509 | INFO     | __main__:run_inference:363 - Generate video chunk-29 done, cost time: 14.46s
# [generate] model denoise per step: 1.7844233512878418s
# [generate] model denoise per step: 1.7940845489501953s
# [generate] model denoise per step: 1.8002443313598633s
# [generate] model denoise per step: 1.7965593338012695s
# [generate] decode video frames: 5.7015180587768555s
# [generate] color correction: 0.046877384185791016s
# [generate] encode motion frames: 1.541926622390747s
# 2026-05-13 10:06:57.065 | INFO     | __main__:run_inference:363 - Generate video chunk-30 done, cost time: 14.47s
# [generate] model denoise per step: 1.782621145248413s
# [generate] model denoise per step: 1.7945456504821777s
# [generate] model denoise per step: 1.7854681015014648s
# [generate] model denoise per step: 1.7982769012451172s
# [generate] decode video frames: 5.71200704574585s
# [generate] color correction: 0.04617047309875488s
# [generate] encode motion frames: 1.544996738433838s
# 2026-05-13 10:07:11.655 | INFO     | __main__:run_inference:363 - Generate video chunk-31 done, cost time: 14.47s
# [generate] model denoise per step: 1.7765486240386963s
# [generate] model denoise per step: 1.7861225605010986s
# [generate] model denoise per step: 1.7910761833190918s
# [generate] model denoise per step: 1.783022165298462s
# [generate] decode video frames: 5.699376106262207s
# [generate] color correction: 0.04687857627868652s
# [generate] encode motion frames: 1.5390887260437012s
# 2026-05-13 10:07:26.169 | INFO     | __main__:run_inference:363 - Generate video chunk-32 done, cost time: 14.43s
# [generate] model denoise per step: 1.7875232696533203s
# [generate] model denoise per step: 1.789186716079712s
# [generate] model denoise per step: 1.7840900421142578s
# [generate] model denoise per step: 1.7916100025177002s
# [generate] decode video frames: 5.686839580535889s
# [generate] color correction: 0.04576611518859863s
# [generate] encode motion frames: 1.5306429862976074s
# 2026-05-13 10:07:40.679 | INFO     | __main__:run_inference:363 - Generate video chunk-33 done, cost time: 14.42s
# [generate] model denoise per step: 1.7703814506530762s
# [generate] model denoise per step: 1.7796025276184082s
# [generate] model denoise per step: 1.7790827751159668s
# [generate] model denoise per step: 1.78511381149292s
# [generate] decode video frames: 5.677698373794556s
# [generate] color correction: 0.046552181243896484s
# [generate] encode motion frames: 1.5318667888641357s
# 2026-05-13 10:07:55.147 | INFO     | __main__:run_inference:363 - Generate video chunk-34 done, cost time: 14.38s
# [generate] model denoise per step: 1.7722420692443848s
# [generate] model denoise per step: 1.7776992321014404s
# [generate] model denoise per step: 1.7836260795593262s
# [generate] model denoise per step: 1.7768113613128662s
# [generate] decode video frames: 5.6817240715026855s
# [generate] color correction: 0.04611396789550781s
# [generate] encode motion frames: 1.5335893630981445s
# 2026-05-13 10:08:09.609 | INFO     | __main__:run_inference:363 - Generate video chunk-35 done, cost time: 14.38s
# [generate] model denoise per step: 1.7734851837158203s
# [generate] model denoise per step: 1.7708086967468262s
# [generate] model denoise per step: 1.7851052284240723s
# [generate] model denoise per step: 1.7833771705627441s
# [generate] decode video frames: 5.672803163528442s
# [generate] color correction: 0.046170949935913086s
# [generate] encode motion frames: 1.5418035984039307s
# 2026-05-13 10:08:24.074 | INFO     | __main__:run_inference:363 - Generate video chunk-36 done, cost time: 14.38s
# [generate] model denoise per step: 1.774036169052124s
# [generate] model denoise per step: 1.7843115329742432s
# [generate] model denoise per step: 1.7863774299621582s
# [generate] model denoise per step: 1.7825541496276855s
# [generate] decode video frames: 5.688566446304321s
# [generate] color correction: 0.046060800552368164s
# [generate] encode motion frames: 1.5298452377319336s
# 2026-05-13 10:08:38.583 | INFO     | __main__:run_inference:363 - Generate video chunk-37 done, cost time: 14.40s
# [generate] model denoise per step: 1.7796285152435303s
# [generate] model denoise per step: 1.7907912731170654s
# [generate] model denoise per step: 1.7854201793670654s
# [generate] model denoise per step: 1.7825944423675537s
# [generate] decode video frames: 5.678226709365845s
# [generate] color correction: 0.04614424705505371s
# [generate] encode motion frames: 1.5317094326019287s
# 2026-05-13 10:08:53.078 | INFO     | __main__:run_inference:363 - Generate video chunk-38 done, cost time: 14.40s
# [generate] model denoise per step: 1.775376319885254s
# [generate] model denoise per step: 1.7834606170654297s
# [generate] model denoise per step: 1.7808241844177246s
# [generate] model denoise per step: 1.7863588333129883s
# [generate] decode video frames: 5.704223155975342s
# [generate] color correction: 0.045798301696777344s
# [generate] encode motion frames: 1.5389776229858398s
# 2026-05-13 10:09:07.588 | INFO     | __main__:run_inference:363 - Generate video chunk-39 done, cost time: 14.42s
# [generate] model denoise per step: 1.7811553478240967s
# [generate] model denoise per step: 1.7852609157562256s
# [generate] model denoise per step: 1.781409502029419s
# [generate] model denoise per step: 1.7856550216674805s
# [generate] decode video frames: 5.685186386108398s
# [generate] color correction: 0.04584908485412598s
# [generate] encode motion frames: 1.5356295108795166s
# 2026-05-13 10:09:22.080 | INFO     | __main__:run_inference:363 - Generate video chunk-40 done, cost time: 14.41s
# [generate] model denoise per step: 1.7841145992279053s
# [generate] model denoise per step: 1.787156105041504s
# [generate] model denoise per step: 1.7851204872131348s
# [generate] model denoise per step: 1.788952112197876s
# [generate] decode video frames: 5.695379972457886s
# [generate] color correction: 0.04599308967590332s
# [generate] encode motion frames: 1.532810926437378s
# 2026-05-13 10:09:36.590 | INFO     | __main__:run_inference:363 - Generate video chunk-41 done, cost time: 14.43s
# [generate] model denoise per step: 1.7821016311645508s
# [generate] model denoise per step: 1.7832136154174805s
# [generate] model denoise per step: 1.7883400917053223s
# [generate] model denoise per step: 1.7898833751678467s
# [generate] decode video frames: 5.690154075622559s
# [generate] color correction: 0.04656863212585449s
# [generate] encode motion frames: 1.5415263175964355s
# 2026-05-13 10:09:51.126 | INFO     | __main__:run_inference:363 - Generate video chunk-42 done, cost time: 14.43s
# [generate] model denoise per step: 1.7886848449707031s
# [generate] model denoise per step: 1.782799243927002s
# [generate] model denoise per step: 1.7807083129882812s
# [generate] model denoise per step: 1.7907335758209229s
# [generate] decode video frames: 5.69071102142334s
# [generate] color correction: 0.04685664176940918s
# [generate] encode motion frames: 1.5385243892669678s
# 2026-05-13 10:10:05.672 | INFO     | __main__:run_inference:363 - Generate video chunk-43 done, cost time: 14.43s
# [generate] model denoise per step: 1.7860527038574219s
# [generate] model denoise per step: 1.782689094543457s
# [generate] model denoise per step: 1.7834053039550781s
# [generate] model denoise per step: 1.7851169109344482s
# [generate] decode video frames: 5.683306694030762s
# [generate] color correction: 0.046370744705200195s
# [generate] encode motion frames: 1.5348734855651855s
# 2026-05-13 10:10:20.167 | INFO     | __main__:run_inference:363 - Generate video chunk-44 done, cost time: 14.41s
# [generate] model denoise per step: 1.7792870998382568s
# [generate] model denoise per step: 1.7921350002288818s
# [generate] model denoise per step: 1.7840323448181152s
# [generate] model denoise per step: 1.7959730625152588s
# [generate] decode video frames: 5.708616495132446s
# [generate] color correction: 0.0462799072265625s
# [generate] encode motion frames: 1.5358459949493408s
# 2026-05-13 10:10:34.704 | INFO     | __main__:run_inference:363 - Generate video chunk-45 done, cost time: 14.45s
# [generate] model denoise per step: 1.7761168479919434s
# [generate] model denoise per step: 1.7845313549041748s
# [generate] model denoise per step: 1.7863166332244873s
# [generate] model denoise per step: 1.7829794883728027s
# [generate] decode video frames: 5.667418956756592s
# [generate] color correction: 0.04590964317321777s
# [generate] encode motion frames: 1.5307705402374268s
# 2026-05-13 10:10:49.173 | INFO     | __main__:run_inference:363 - Generate video chunk-46 done, cost time: 14.38s
# [generate] model denoise per step: 1.7659320831298828s
# [generate] model denoise per step: 1.7826247215270996s
# [generate] model denoise per step: 1.782085657119751s
# [generate] model denoise per step: 1.7796430587768555s
# [generate] decode video frames: 5.669145345687866s
# [generate] color correction: 0.0465848445892334s
# [generate] encode motion frames: 1.5358078479766846s
# 2026-05-13 10:11:03.627 | INFO     | __main__:run_inference:363 - Generate video chunk-47 done, cost time: 14.37s
# [generate] model denoise per step: 1.773320198059082s
# [generate] model denoise per step: 1.781921148300171s
# [generate] model denoise per step: 1.7779450416564941s
# [generate] model denoise per step: 1.778639316558838s
# [generate] decode video frames: 5.675679683685303s
# [generate] color correction: 0.04551863670349121s
# [generate] encode motion frames: 1.5287799835205078s
# 2026-05-13 10:11:18.127 | INFO     | __main__:run_inference:363 - Generate video chunk-48 done, cost time: 14.37s
# [generate] model denoise per step: 1.7814574241638184s
# [generate] model denoise per step: 1.7794544696807861s
# [generate] model denoise per step: 1.7907261848449707s
# [generate] model denoise per step: 1.7696564197540283s
# [generate] decode video frames: 5.653768301010132s
# [generate] color correction: 0.04540252685546875s
# [generate] encode motion frames: 1.5287718772888184s
# 2026-05-13 10:11:32.581 | INFO     | __main__:run_inference:363 - Generate video chunk-49 done, cost time: 14.36s
# [generate] model denoise per step: 1.7715411186218262s
# [generate] model denoise per step: 1.782261610031128s
# [generate] model denoise per step: 1.7838687896728516s
# [generate] model denoise per step: 1.772892713546753s
# [generate] decode video frames: 5.65626335144043s
# [generate] color correction: 0.04523277282714844s
# [generate] encode motion frames: 1.5318183898925781s
# 2026-05-13 10:11:47.021 | INFO     | __main__:run_inference:363 - Generate video chunk-50 done, cost time: 14.35s
# [generate] model denoise per step: 1.7741761207580566s
# [generate] model denoise per step: 1.7728657722473145s
# [generate] model denoise per step: 1.7838077545166016s
# [generate] model denoise per step: 1.7778167724609375s
# [generate] decode video frames: 5.689645051956177s
# [generate] color correction: 0.04599356651306152s
# [generate] encode motion frames: 1.5354461669921875s
# 2026-05-13 10:12:01.494 | INFO     | __main__:run_inference:363 - Generate video chunk-51 done, cost time: 14.39s
# [generate] model denoise per step: 1.7708592414855957s
# [generate] model denoise per step: 1.7799396514892578s
# [generate] model denoise per step: 1.784440040588379s
# [generate] model denoise per step: 1.7836885452270508s
# [generate] decode video frames: 5.688422679901123s
# [generate] color correction: 0.046688079833984375s
# [generate] encode motion frames: 1.532196044921875s
# 2026-05-13 10:12:15.971 | INFO     | __main__:run_inference:363 - Generate video chunk-52 done, cost time: 14.39s
# [generate] model denoise per step: 1.7768833637237549s
# [generate] model denoise per step: 1.785642147064209s
# [generate] model denoise per step: 1.7916924953460693s
# [generate] model denoise per step: 1.7803635597229004s
# [generate] decode video frames: 5.678349018096924s
# [generate] color correction: 0.04535865783691406s
# [generate] encode motion frames: 1.5313189029693604s
# 2026-05-13 10:12:30.454 | INFO     | __main__:run_inference:363 - Generate video chunk-53 done, cost time: 14.40s
# [generate] model denoise per step: 1.7813663482666016s
# [generate] model denoise per step: 1.773317575454712s
# [generate] model denoise per step: 1.7809596061706543s
# [generate] model denoise per step: 1.7770442962646484s
# [generate] decode video frames: 5.677453279495239s
# [generate] color correction: 0.04702425003051758s
# [generate] encode motion frames: 1.5481154918670654s
# 2026-05-13 10:12:44.955 | INFO     | __main__:run_inference:363 - Generate video chunk-54 done, cost time: 14.39s
# [generate] model denoise per step: 1.7757384777069092s
# [generate] model denoise per step: 1.7725529670715332s
# [generate] model denoise per step: 1.7806413173675537s
# [generate] model denoise per step: 1.7773971557617188s
# [generate] decode video frames: 5.671015739440918s
# [generate] color correction: 0.047263383865356445s
# [generate] encode motion frames: 1.5321264266967773s
# 2026-05-13 10:12:59.430 | INFO     | __main__:run_inference:363 - Generate video chunk-55 done, cost time: 14.36s
# [generate] model denoise per step: 1.76924729347229s
# [generate] model denoise per step: 1.782541275024414s
# [generate] model denoise per step: 1.7816886901855469s
# [generate] model denoise per step: 1.779036045074463s
# [generate] decode video frames: 5.674349546432495s
# [generate] color correction: 0.04535269737243652s
# [generate] encode motion frames: 1.5321276187896729s
# 2026-05-13 10:13:13.889 | INFO     | __main__:run_inference:363 - Generate video chunk-56 done, cost time: 14.37s
# [generate] model denoise per step: 1.7759006023406982s
# [generate] model denoise per step: 1.7780847549438477s
# [generate] model denoise per step: 1.7866005897521973s
# [generate] model denoise per step: 1.7713212966918945s
# [generate] decode video frames: 5.680356502532959s
# [generate] color correction: 0.046912193298339844s
# [generate] encode motion frames: 1.5359585285186768s
# 2026-05-13 10:13:28.366 | INFO     | __main__:run_inference:363 - Generate video chunk-57 done, cost time: 14.38s
# [generate] model denoise per step: 1.778825283050537s
# [generate] model denoise per step: 1.7779462337493896s
# [generate] model denoise per step: 1.7827484607696533s
# [generate] model denoise per step: 1.7814619541168213s
# [generate] decode video frames: 5.6587138175964355s
# [generate] color correction: 0.04621577262878418s
# [generate] encode motion frames: 1.5202858448028564s
# 2026-05-13 10:13:42.809 | INFO     | __main__:run_inference:363 - Generate video chunk-58 done, cost time: 14.35s
# [generate] model denoise per step: 1.7631933689117432s
# [generate] model denoise per step: 1.763660192489624s
# [generate] model denoise per step: 1.762394666671753s
# [generate] model denoise per step: 1.7553308010101318s
# [generate] decode video frames: 5.5871758460998535s
# [generate] color correction: 0.04525303840637207s
# [generate] encode motion frames: 1.5084357261657715s
# 2026-05-13 10:13:57.094 | INFO     | __main__:run_inference:363 - Generate video chunk-59 done, cost time: 14.19s
# [generate] model denoise per step: 1.749211072921753s
# [generate] model denoise per step: 1.7588865756988525s
# [generate] model denoise per step: 1.7579128742218018s
# [generate] model denoise per step: 1.7628233432769775s
# [generate] decode video frames: 5.629374265670776s
# [generate] color correction: 0.04605674743652344s
# [generate] encode motion frames: 1.5254645347595215s
# 2026-05-13 10:14:11.422 | INFO     | __main__:run_inference:363 - Generate video chunk-60 done, cost time: 14.24s
# [generate] model denoise per step: 1.7731668949127197s
# [generate] model denoise per step: 1.7818739414215088s
# [generate] model denoise per step: 1.783388376235962s
# [generate] model denoise per step: 1.7851734161376953s
# [generate] decode video frames: 5.718833684921265s
# [generate] color correction: 0.04579782485961914s
# [generate] encode motion frames: 1.540619134902954s
# 2026-05-13 10:14:25.989 | INFO     | __main__:run_inference:363 - Generate video chunk-61 done, cost time: 14.44s
# [generate] model denoise per step: 1.8009274005889893s
# [generate] model denoise per step: 1.803135633468628s
# [generate] model denoise per step: 1.821117877960205s
# [generate] model denoise per step: 1.8188960552215576s
# [generate] decode video frames: 5.759658098220825s
# [generate] color correction: 0.0474095344543457s
# [generate] encode motion frames: 1.5424401760101318s
# 2026-05-13 10:14:40.679 | INFO     | __main__:run_inference:363 - Generate video chunk-62 done, cost time: 14.60s
# [generate] model denoise per step: 1.792370080947876s
# [generate] model denoise per step: 1.7954366207122803s
# [generate] model denoise per step: 1.796968936920166s
# [generate] model denoise per step: 1.8042974472045898s
# [generate] decode video frames: 5.723439931869507s
# [generate] color correction: 0.045549869537353516s
# [generate] encode motion frames: 1.5347437858581543s
# 2026-05-13 10:14:55.267 | INFO     | __main__:run_inference:363 - Generate video chunk-63 done, cost time: 14.50s
# [generate] model denoise per step: 1.781165599822998s
# [generate] model denoise per step: 1.7806456089019775s
# [generate] model denoise per step: 1.7821376323699951s
# [generate] model denoise per step: 1.779101848602295s
# [generate] decode video frames: 5.638174533843994s
# [generate] color correction: 0.04641437530517578s
# [generate] encode motion frames: 1.5214803218841553s
# 2026-05-13 10:15:09.690 | INFO     | __main__:run_inference:363 - Generate video chunk-64 done, cost time: 14.34s
# [generate] model denoise per step: 1.7667059898376465s
# [generate] model denoise per step: 1.7587804794311523s
# [generate] model denoise per step: 1.7634592056274414s
# [generate] model denoise per step: 1.7673745155334473s
# [generate] decode video frames: 5.611583709716797s
# [generate] color correction: 0.04548287391662598s
# [generate] encode motion frames: 1.5194637775421143s
# 2026-05-13 10:15:24.018 | INFO     | __main__:run_inference:363 - Generate video chunk-65 done, cost time: 14.24s
# [generate] model denoise per step: 1.761687994003296s
# [generate] model denoise per step: 1.7658252716064453s
# [generate] model denoise per step: 1.764739751815796s
# [generate] model denoise per step: 1.7592401504516602s
# [generate] decode video frames: 5.622601747512817s
# [generate] color correction: 0.0461575984954834s
# [generate] encode motion frames: 1.5248222351074219s
# 2026-05-13 10:15:38.365 | INFO     | __main__:run_inference:363 - Generate video chunk-66 done, cost time: 14.25s
# [generate] model denoise per step: 1.7714269161224365s
# [generate] model denoise per step: 1.7626006603240967s
# [generate] model denoise per step: 1.7630743980407715s
# [generate] model denoise per step: 1.7727878093719482s
# [generate] decode video frames: 5.628551959991455s
# [generate] color correction: 0.046605587005615234s
# [generate] encode motion frames: 1.5172419548034668s
# 2026-05-13 10:15:52.752 | INFO     | __main__:run_inference:363 - Generate video chunk-67 done, cost time: 14.27s
# [generate] model denoise per step: 1.7607650756835938s
# [generate] model denoise per step: 1.772068738937378s
# [generate] model denoise per step: 1.7658956050872803s
# [generate] model denoise per step: 1.7756755352020264s
# [generate] decode video frames: 5.647323131561279s
# [generate] color correction: 0.04592609405517578s
# [generate] encode motion frames: 1.5250916481018066s
# 2026-05-13 10:16:07.136 | INFO     | __main__:run_inference:363 - Generate video chunk-68 done, cost time: 14.30s
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'gradio_results/res_20260513-101607-194_temp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.1.100
#   Duration: 00:01:06.24, start: 0.000000, bitrate: 874 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x512, 873 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc61.3.100 libx264
# Guessed Channel Layout for Input Stream #1.0 : mono
# Input #1, wav, from '/tmp/gradio/92ab0b39a8952902130b9a22ed93f12bad20895b079c0286c88e27e789f15f82/podcast_sichuan_16k.wav':
#   Duration: 00:01:05.92, bitrate: 256 kb/s
#   Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to 'gradio_results/res_20260513-101607-194.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x512, q=2-31, 873 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc61.3.100 libx264
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 16000 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac
# frame= 1648 fps=0.0 q=-1.0 Lsize=    7713kB time=00:01:05.88 bitrate= 959.1kbits/s speed= 216x
# video:7055kB audio:629kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.384711%
# [aac @ 0x5afd0143cb40] Qavg: 19119.363
# 2026-05-13 10:16:38.035 | INFO     | __main__:run_inference:377 - Saved to gradio_results/res_20260513-101607-194.mp4
# 2026-05-13 10:16:38.037 | INFO     | __main__:_composite_to_original:45 - Original 1251x1431 is ~square, skipping composite

# %% [markdown]
# ---
#
# <div align="center">
#
# ### 🎉 Enjoyed this notebook?
#
# If this was helpful, please **⭐ star the repo** and **subscribe** for more free AI tools & tutorials!
#
#   <a href="https://www.youtube.com/@aiquestacademy?sub_confirmation=1">
#     <img src="https://img.shields.io/badge/▶%20Subscribe%20on%20YouTube-FF0000?style=for-the-badge&logo=youtube&logoColor=white" />
#   </a>
#   &nbsp;
#   <a href="https://x.com/aiquestacademy">
#     <img src="https://img.shields.io/badge/Follow%20on%20𝕏-0000?style=for-the-badge&logo=x&logoColor=white" />
#   </a>
#
# **Made with ❤️ by AIQUEST** | [@aiquestacademy](https://youtube.com/@aiquestacademy)
#
# </div>
